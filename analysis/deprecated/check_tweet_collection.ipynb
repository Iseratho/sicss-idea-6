# %%
import pandas as pd

# %%
df_id = pd.read_json("test1_flat.json", lines=True, dtype={"id": str})
df_id
# Out:
#                     id reply_settings  \
# 0  1314493025700077568       everyone
# 1  1277997708649865218       everyone
#
#                                       public_metrics  possibly_sensitive  \
# 0  {'retweet_count': 8, 'reply_count': 3, 'like_c...               False
# 1  {'retweet_count': 3, 'reply_count': 5, 'like_c...               False
#
#              author_id                                context_annotations  \
# 0  1194759472087998464  [{'domain': {'id': '10', 'name': 'Person', 'de...
# 1  1194759472087998464                                                NaN
#
#                                    referenced_tweets      conversation_id  \
# 0  [{'type': 'replied_to', 'id': '131447772937129...  1314477726678614016
# 1                                                NaN  1277997708649865216
#
#                                             entities               source  \
# 0  {'mentions': [{'start': 0, 'end': 12, 'usernam...  Twitter for Android
# ...

# %%
df_username = pd.read_json("test2_flat.json", lines=True, dtype={"id": str})
df_username
# Out:
#    in_reply_to_user_id                                           entities  \
# 0          470801601.0  {'mentions': [{'start': 0, 'end': 12, 'usernam...
# 1                  NaN  {'mentions': [{'start': 61, 'end': 72, 'userna...
#
#                 source                                  referenced_tweets  \
# 0  Twitter for Android  [{'type': 'replied_to', 'id': '131447772937129...
# 1      Twitter Web App                                                NaN
#
#                     id reply_settings lang      conversation_id  \
# 0  1314493025700077568       everyone   en  1314477726678614016
# 1  1277997708649865218       everyone   en  1277997708649865216
#
#              author_id  possibly_sensitive  \
# 0  1194759472087998464               False
# 1  1194759472087998464               False
#
#                                                 text  \
# 0  @AlyAShields @BetsiCadwaladr @healthdpt @NICEC...
# 1  Delighted to hear that an agreement has been r...
#
# ...

# %%
df_username["text"].values
# Out:
# array(['@AlyAShields @BetsiCadwaladr @healthdpt @NICEComms @CommonsHealth @MQmentalhealth @NHSEngland @IanLangITVWales Your voice has been heard @AlyAShields! Thanks for taking the time to meet me. We are working on achieving recognition for this through the APPG.\n\n@RuthCadbury',
#        'Delighted to hear that an agreement has been reached between @NHSEngland and @vertexpharma over #cysticfibrosis medicine #Kaftrio (#Trikafta).\n\nThis is a step change in effective treatment and outcomes for patients.\n\nNow to bring that to #Wales.'],
#       dtype=object)
